# %% [markdown]
# #Curso de Inteligencia Artificial y Machine Learning
# ### EOI - Garantía Juvenil
# Módulo 7 - Deep Learning para Visión Artificial
#
# Proyecto nº3

# %% [markdown]
# # Clasificación de imágenes con modelos de Deep Learning
#
# En este proyecto, se pide contruir un modelo clasificador para distinguir entre imágenes de gatos y perros. Para ello, utilizaremos un dataset reducido extraido del famoso dataset de la competición de Kaggle de 2013 lanzada por Google "Dogs vs Cats"

# %% [markdown]
# Primero, importaremos las bibliotecas necesarias para este ejercicio

# %%
from keras import layers
from keras import models
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Para cargar los datos, ejecuta la siguiente celda:

# %%
# Ejecuta esto para descargarte el dataset. Podrás encontrar los archivos en el
# directorio correspondiente en la pestaña de Archivos en el menú de la izquierda.

# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip

# !unzip /tmp/cats_and_dogs_filtered.zip

# %% [markdown]
# Te recomendamos crear las variables de las rutas de los directorios de datos de entrenamiento y validación:

# %%
train_dir = '/content/cats_and_dogs_filtered/train'
validation_dir = '/content/cats_and_dogs_filtered/validation'

# %% [markdown]
# ## 1. Modelo convolucional normal

# %% [markdown]
# Vas a entrenar un modelo de red neuronal convolucional con el dataset mencionado. Para ello, necesitamos hacer un preprocesamiento de las imágenes utilizando el módulo ImageDataGenerator que creará un generador que recorrerá los directorios de imágenes creados, adaptando las imágenes para que sean reconocibles por el modelo.

# %%
train_gen = ImageDataGenerator(rescale=1/255).flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 20,
    class_mode = 'binary')

valid_gen = ImageDataGenerator(rescale = 1/255).flow_from_directory(
    validation_dir,
    target_size = (150,150),
    batch_size = 20,
    class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

batch_X, batch_y = next(train_gen)

# %%
batch_X.shape
# Out:
# (20, 150, 150, 3)

# %%
plt.imshow(batch_X[0])

# %% [markdown]
# 1.1. Construye un modelo que contenga capas convolucionales, de pooling y neuronales, incluyendo, al menos, dos capas convolucionales y dos capas neuronales.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import tensorflow as tf
from tensorflow import keras

# %%
# Construcción del modelo
def get_conv_model():
  model = Sequential()
  # ENCODER
  model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(32, (3, 3), activation='relu'))
  model.add(MaxPooling2D((3, 3)))

  # DECODER
  model.add(Flatten())
  model.add(Dense(32, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))

  # Compilar el modelo
  model.compile(loss='binary_crossentropy',
                optimizer=optimizers.RMSprop(learning_rate=1e-4),
                metrics=['accuracy'])

  return model

# %% [markdown]
# 1.2. Compila el modelo usando función de coste 'binary_crossentropy', optimizador RMSprop (puedes hacerlo usando optimizer = optimizers.RMSprop(learning_rate = 1e-4), y métrica 'accuracy'

# %%
# input (None, 150, 150, 3)
model = get_conv_model()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 64)      1792
#
#  max_pooling2d_6 (MaxPoolin  (None, 74, 74, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 32)        18464
#
#  max_pooling2d_7 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_6 (Dense)             (None, 32)                589856
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 610145 (2.33 MB)
# Trainable params: 610145 (2.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# 1.3. Entrena el modelo con datos de entrenamiento y test preparados, utilizando, al menos, 30 epochs, y guarda los resultados de éste en una variable "history"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Parar el entrenamiento despues de 10 epochs sin mejorar el val_loss un 0.001
es = EarlyStopping(patience=10,
                   monitor='val_loss',
                   min_delta=0.001,
                   restore_best_weights=True)
# Guardar el mejor modelo obtenido en el entrenamiento
checkpoint = ModelCheckpoint('/tmp/my_best_model',
                             monitor='val_loss',
                             save_best_only=True)

# %%
# Entrenamiento del modelo
history = model.fit(
      train_gen,
      steps_per_epoch=100,
      epochs=9999, ## Epochs "ilimitadas"
      validation_data=valid_gen,
      validation_steps=50,
      callbacks=[es, checkpoint])
# Out:
# Epoch 1/9999
# 100/100 [==============================] - 7s 62ms/step - loss: 0.6866 - accuracy: 0.5440 - val_loss: 0.6714 - val_accuracy: 0.6040
# Epoch 2/9999
# 100/100 [==============================] - 7s 73ms/step - loss: 0.6604 - accuracy: 0.5975 - val_loss: 0.6375 - val_accuracy: 0.6500
# Epoch 3/9999
# 100/100 [==============================] - 5s 54ms/step - loss: 0.6270 - accuracy: 0.6510 - val_loss: 0.6720 - val_accuracy: 0.5870
# Epoch 4/9999
# 100/100 [==============================] - 7s 70ms/step - loss: 0.6015 - accuracy: 0.6860 - val_loss: 0.6011 - val_accuracy: 0.6860
# Epoch 5/9999
# 100/100 [==============================] - 6s 61ms/step - loss: 0.5768 - accuracy: 0.7025 - val_loss: 0.6010 - val_accuracy: 0.6760
# Epoch 6/9999
# 100/100 [==============================] - 7s 70ms/step - loss: 0.5454 - accuracy: 0.7330 - val_loss: 0.5669 - val_accuracy: 0.7160
# Epoch 7/9999
# 100/100 [==============================] - 5s 52ms/step - loss: 0.5304 - accuracy: 0.7410 - val_loss: 0.5918 - val_accuracy: 0.6550
# Epoch 8/9999
# 100/100 [==============================] - 7s 69ms/step - loss: 0.5085 - accuracy: 0.7685 - val_loss: 0.5474 - val_accuracy: 0.7410
# Epoch 9/9999
# 100/100 [==============================] - 6s 59ms/step - loss: 0.4911 - accuracy: 0.7720 - val_loss: 0.5444 - val_accuracy: 0.7150
# Epoch 10/9999
# 100/100 [==============================] - 6s 63ms/step - loss: 0.4685 - accuracy: 0.7900 - val_loss: 0.6221 - val_accuracy: 0.6450
# Epoch 11/9999
# 100/100 [==============================] - 5s 52ms/step - loss: 0.4503 - accuracy: 0.8025 - val_loss: 0.5956 - val_accuracy: 0.6950
# Epoch 12/9999
# 100/100 [==============================] - 7s 69ms/step - loss: 0.4303 - accuracy: 0.8135 - val_loss: 0.5217 - val_accuracy: 0.7320
# Epoch 13/9999
# 100/100 [==============================] - 5s 53ms/step - loss: 0.4117 - accuracy: 0.8180 - val_loss: 0.5235 - val_accuracy: 0.7260
# Epoch 14/9999
# 100/100 [==============================] - 7s 67ms/step - loss: 0.3957 - accuracy: 0.8250 - val_loss: 0.5201 - val_accuracy: 0.7500
# Epoch 15/9999
# 100/100 [==============================] - 7s 70ms/step - loss: 0.3853 - accuracy: 0.8355 - val_loss: 0.5180 - val_accuracy: 0.7400
# Epoch 16/9999
# 100/100 [==============================] - 6s 63ms/step - loss: 0.3673 - accuracy: 0.8510 - val_loss: 0.6035 - val_accuracy: 0.7030
# Epoch 17/9999
# 100/100 [==============================] - 5s 53ms/step - loss: 0.3545 - accuracy: 0.8495 - val_loss: 0.6137 - val_accuracy: 0.6880
# Epoch 18/9999
# 100/100 [==============================] - 6s 60ms/step - loss: 0.3411 - accuracy: 0.8540 - val_loss: 0.5283 - val_accuracy: 0.7300
# Epoch 19/9999
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3240 - accuracy: 0.8730 - val_loss: 0.5383 - val_accuracy: 0.7380
# Epoch 20/9999
# 100/100 [==============================] - 6s 58ms/step - loss: 0.3078 - accuracy: 0.8840 - val_loss: 0.5279 - val_accuracy: 0.7420
# Epoch 21/9999
# 100/100 [==============================] - 5s 52ms/step - loss: 0.3016 - accuracy: 0.8755 - val_loss: 0.5319 - val_accuracy: 0.7390
# Epoch 22/9999
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2829 - accuracy: 0.8935 - val_loss: 0.5343 - val_accuracy: 0.7500
# Epoch 23/9999
# 100/100 [==============================] - 5s 53ms/step - loss: 0.2714 - accuracy: 0.8995 - val_loss: 0.5927 - val_accuracy: 0.7240
# Epoch 24/9999
# 100/100 [==============================] - 6s 63ms/step - loss: 0.2564 - accuracy: 0.9045 - val_loss: 0.5374 - val_accuracy: 0.7460
# Epoch 25/9999
# 100/100 [==============================] - 5s 54ms/step - loss: 0.2405 - accuracy: 0.9210 - val_loss: 0.5639 - val_accuracy: 0.7400

# %% [markdown]
# Vamos a representar los resultados del entrenamiento. Te dejamos un código de ejemplo, en el que puedes adaptar los nombres de las variables que corresponda.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
print(f"Max validation accuracy is {max(val_acc)}")
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo',label='Training accuracy')
plt.plot(epochs, val_acc, 'r',label='Validation accuracy')
plt.title('Training and validation accuracy - model')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo',label='Training loss')
plt.plot(epochs, val_loss, 'r',label='Validation loss')
plt.title('Training and validation loss - model')
plt.legend()
# Out:
# Max validation accuracy is 0.75

# %% [markdown]
# 1.4. ¿Qué conclusiones puedes sacar viendo las gráficas?¿Crees que hay overfitting?¿A qué crees que es debido?

# %% [markdown]
# - Si creo que existe un claro overfitting, sobretodo viendo lo que divergen ambas graficas a partir del epoch 8 mas o menos. El overfitting puede estar debido a un entrenamiento con tan poco material y poco variado.

# %% [markdown]
# ## 2. Modelo con Data Augmentation

# %% [markdown]
# Ahora vamos a intentar mejorar el modelo recurriendo a la técnica del "Data Augmentation" o aumentar el número de imágenes disponibles para el entrenamiento modificando ligeramente las que ya tenemos. Para ello, creamos, de nuevo, un generador, pero esta vez, con argumentos de modificación de las imágenes.

# %%
train_datagen = ImageDataGenerator(rescale=1/255,
                               width_shift_range=0.2,
                               height_shift_range=0.2,
                               rotation_range=20,
                               shear_range=0.2,
                               horizontal_flip=True,
                               zoom_range=0.2)
valid_datagen = ImageDataGenerator(rescale=1/255)

train_gen = train_datagen.flow_from_directory(train_dir,
                                              target_size = (150,150),
                                              batch_size = 32,
                                              class_mode = 'binary')

valid_gen = valid_datagen.flow_from_directory(validation_dir,
                                                target_size = (150,150),
                                                batch_size = 32,
                                                class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# Echamos un vistazo a las imágenes tras las modificaciones

# %%
import matplotlib.pyplot as plt

batchX, batchY = next(train_gen)

plt.imshow(batchX[0])
print(batchY[0])
# Out:
# 0.0

# %% [markdown]
# 2.1. Construye un modelo similar al anterior, pero, esta vez, incluye una capa de dropout justo antes de la capa neuronal de mayor número de neuronas. Utiliza los mismos parámetros para la compilación, y realiza el entrenamiento, esta vez, con 100 epochs.

# %%
def get_conv_model_with_drop():
  model = Sequential()
  # ENCODER
  model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D((3, 3)))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D((3, 3)))

  # DECODER
  model.add(Flatten())
  model.add(Dropout(0.1))
  model.add(Dense(32, activation='relu'))
  model.add(Dropout(0.1))
  model.add(Dense(1, activation='sigmoid'))

  # Compilar el modelo
  model.compile(loss='binary_crossentropy',
                optimizer=optimizers.RMSprop(learning_rate=1e-4),
                metrics=['accuracy'])

  return model

# %%
# Construcción del modelo
model_with_dropout = get_conv_model_with_drop()
model_with_dropout.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 148, 148, 64)      1792
#
#  max_pooling2d_25 (MaxPooli  (None, 74, 74, 64)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 72, 72, 64)        36928
#
#  max_pooling2d_26 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 22, 22, 64)        36928
#
#  max_pooling2d_27 (MaxPooli  (None, 7, 7, 64)          0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 3136)              0
#
#  dropout_18 (Dropout)        (None, 3136)              0
#
#  dense_20 (Dense)            (None, 32)                100384
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_21 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 176065 (687.75 KB)
# Trainable params: 176065 (687.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Parar el entrenamiento despues de 10 epochs sin mejorar el val_loss un 0.001
es = EarlyStopping(patience=10,
                   monitor='val_loss',
                   min_delta=0.001,
                   restore_best_weights=True)
# Guardar el mejor modelo obtenido en el entrenamiento
checkpoint = ModelCheckpoint('/tmp/my_best_model',
                             monitor='val_loss',
                             save_best_only=True)

# %%
# Entrenamiento del modelo
history_with_dropout = model_with_dropout.fit(
      train_gen,
      steps_per_epoch=len(train_gen), ## Soluciona error out of memory
      epochs=100,
      validation_data=valid_gen,
      validation_steps=len(valid_gen),
      callbacks=[es, checkpoint])
# Out:
# Epoch 1/100
# 63/63 [==============================] - 20s 280ms/step - loss: 0.6937 - accuracy: 0.5035 - val_loss: 0.6891 - val_accuracy: 0.5310
# Epoch 2/100
# 63/63 [==============================] - 17s 273ms/step - loss: 0.6895 - accuracy: 0.5225 - val_loss: 0.6862 - val_accuracy: 0.5000
# Epoch 3/100
# 63/63 [==============================] - 16s 260ms/step - loss: 0.6849 - accuracy: 0.5575 - val_loss: 0.6725 - val_accuracy: 0.6340
# Epoch 4/100
# 63/63 [==============================] - 17s 264ms/step - loss: 0.6802 - accuracy: 0.5640 - val_loss: 0.6635 - val_accuracy: 0.6380
# Epoch 5/100
# 63/63 [==============================] - 17s 268ms/step - loss: 0.6749 - accuracy: 0.5660 - val_loss: 0.6521 - val_accuracy: 0.6330
# Epoch 6/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.6731 - accuracy: 0.5715 - val_loss: 0.6542 - val_accuracy: 0.5890
# Epoch 7/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.6704 - accuracy: 0.5775 - val_loss: 0.6744 - val_accuracy: 0.5310
# Epoch 8/100
# 63/63 [==============================] - 17s 266ms/step - loss: 0.6645 - accuracy: 0.5930 - val_loss: 0.6580 - val_accuracy: 0.5660
# Epoch 9/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.6638 - accuracy: 0.5925 - val_loss: 0.6305 - val_accuracy: 0.6710
# Epoch 10/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.6521 - accuracy: 0.6050 - val_loss: 0.6389 - val_accuracy: 0.6090
# Epoch 11/100
# 63/63 [==============================] - 16s 257ms/step - loss: 0.6552 - accuracy: 0.6060 - val_loss: 0.6195 - val_accuracy: 0.6590
# Epoch 12/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.6494 - accuracy: 0.6170 - val_loss: 0.6198 - val_accuracy: 0.6380
# Epoch 13/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.6497 - accuracy: 0.6180 - val_loss: 0.6055 - val_accuracy: 0.6750
# Epoch 14/100
# 63/63 [==============================] - 18s 285ms/step - loss: 0.6367 - accuracy: 0.6310 - val_loss: 0.6250 - val_accuracy: 0.6190
# Epoch 15/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.6254 - accuracy: 0.6515 - val_loss: 0.6055 - val_accuracy: 0.6390
# Epoch 16/100
# 63/63 [==============================] - 16s 256ms/step - loss: 0.6265 - accuracy: 0.6360 - val_loss: 0.5830 - val_accuracy: 0.6820
# Epoch 17/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.6158 - accuracy: 0.6615 - val_loss: 0.6735 - val_accuracy: 0.5660
# Epoch 18/100
# 63/63 [==============================] - 16s 253ms/step - loss: 0.6150 - accuracy: 0.6590 - val_loss: 0.5754 - val_accuracy: 0.6940
# Epoch 19/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.6080 - accuracy: 0.6725 - val_loss: 0.5780 - val_accuracy: 0.6990
# Epoch 20/100
# 63/63 [==============================] - 17s 271ms/step - loss: 0.6044 - accuracy: 0.6840 - val_loss: 0.5625 - val_accuracy: 0.7190
# Epoch 21/100
# 63/63 [==============================] - 17s 263ms/step - loss: 0.6021 - accuracy: 0.6730 - val_loss: 0.5568 - val_accuracy: 0.7250
# Epoch 22/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.5980 - accuracy: 0.6865 - val_loss: 0.5658 - val_accuracy: 0.6980
# Epoch 23/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.5893 - accuracy: 0.6895 - val_loss: 0.5816 - val_accuracy: 0.6790
# Epoch 24/100
# 63/63 [==============================] - 17s 268ms/step - loss: 0.5836 - accuracy: 0.7040 - val_loss: 0.5426 - val_accuracy: 0.7340
# Epoch 25/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.5765 - accuracy: 0.6985 - val_loss: 0.5459 - val_accuracy: 0.7180
# Epoch 26/100
# 63/63 [==============================] - 16s 253ms/step - loss: 0.5745 - accuracy: 0.6900 - val_loss: 0.5456 - val_accuracy: 0.7100
# Epoch 27/100
# 63/63 [==============================] - 17s 272ms/step - loss: 0.5821 - accuracy: 0.6970 - val_loss: 0.5425 - val_accuracy: 0.7200
# Epoch 28/100
# 63/63 [==============================] - 16s 257ms/step - loss: 0.5605 - accuracy: 0.7265 - val_loss: 0.5295 - val_accuracy: 0.7340
# Epoch 29/100
# 63/63 [==============================] - 16s 255ms/step - loss: 0.5692 - accuracy: 0.7095 - val_loss: 0.5366 - val_accuracy: 0.7220
# Epoch 30/100
# 63/63 [==============================] - 17s 266ms/step - loss: 0.5652 - accuracy: 0.7070 - val_loss: 0.5233 - val_accuracy: 0.7380
# Epoch 31/100
# 63/63 [==============================] - 16s 253ms/step - loss: 0.5583 - accuracy: 0.7045 - val_loss: 0.5282 - val_accuracy: 0.7270
# Epoch 32/100
# 63/63 [==============================] - 16s 255ms/step - loss: 0.5660 - accuracy: 0.7020 - val_loss: 0.5187 - val_accuracy: 0.7480
# Epoch 33/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.5534 - accuracy: 0.7190 - val_loss: 0.5154 - val_accuracy: 0.7400
# Epoch 34/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5526 - accuracy: 0.7130 - val_loss: 0.5139 - val_accuracy: 0.7380
# Epoch 35/100
# 63/63 [==============================] - 16s 255ms/step - loss: 0.5470 - accuracy: 0.7270 - val_loss: 0.5118 - val_accuracy: 0.7390
# Epoch 36/100
# 63/63 [==============================] - 16s 255ms/step - loss: 0.5512 - accuracy: 0.7160 - val_loss: 0.5098 - val_accuracy: 0.7420
# Epoch 37/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5493 - accuracy: 0.7165 - val_loss: 0.5232 - val_accuracy: 0.7290
# Epoch 38/100
# 63/63 [==============================] - 18s 291ms/step - loss: 0.5479 - accuracy: 0.7170 - val_loss: 0.5361 - val_accuracy: 0.7160
# Epoch 39/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5554 - accuracy: 0.7115 - val_loss: 0.5537 - val_accuracy: 0.6990
# Epoch 40/100
# 63/63 [==============================] - 17s 271ms/step - loss: 0.5341 - accuracy: 0.7250 - val_loss: 0.5579 - val_accuracy: 0.7110
# Epoch 41/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5457 - accuracy: 0.7235 - val_loss: 0.5465 - val_accuracy: 0.7060
# Epoch 42/100
# 63/63 [==============================] - 18s 292ms/step - loss: 0.5490 - accuracy: 0.7175 - val_loss: 0.5081 - val_accuracy: 0.7330
# Epoch 43/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5233 - accuracy: 0.7360 - val_loss: 0.4906 - val_accuracy: 0.7500
# Epoch 44/100
# 63/63 [==============================] - 17s 267ms/step - loss: 0.5220 - accuracy: 0.7425 - val_loss: 0.4972 - val_accuracy: 0.7510
# Epoch 45/100
# 63/63 [==============================] - 17s 270ms/step - loss: 0.5402 - accuracy: 0.7295 - val_loss: 0.5064 - val_accuracy: 0.7370
# Epoch 46/100
# 63/63 [==============================] - 16s 256ms/step - loss: 0.5364 - accuracy: 0.7345 - val_loss: 0.5032 - val_accuracy: 0.7500
# Epoch 47/100
# 63/63 [==============================] - 17s 263ms/step - loss: 0.5222 - accuracy: 0.7395 - val_loss: 0.5068 - val_accuracy: 0.7320
# Epoch 48/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.5264 - accuracy: 0.7245 - val_loss: 0.5053 - val_accuracy: 0.7450
# Epoch 49/100
# 63/63 [==============================] - 16s 258ms/step - loss: 0.5181 - accuracy: 0.7570 - val_loss: 0.4915 - val_accuracy: 0.7450
# Epoch 50/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.5236 - accuracy: 0.7400 - val_loss: 0.4947 - val_accuracy: 0.7490
# Epoch 51/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.5146 - accuracy: 0.7425 - val_loss: 0.5052 - val_accuracy: 0.7400
# Epoch 52/100
# 63/63 [==============================] - 17s 268ms/step - loss: 0.5154 - accuracy: 0.7465 - val_loss: 0.4810 - val_accuracy: 0.7510
# Epoch 53/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.5126 - accuracy: 0.7460 - val_loss: 0.4775 - val_accuracy: 0.7560
# Epoch 54/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5114 - accuracy: 0.7450 - val_loss: 0.4721 - val_accuracy: 0.7650
# Epoch 55/100
# 63/63 [==============================] - 17s 267ms/step - loss: 0.5071 - accuracy: 0.7560 - val_loss: 0.4952 - val_accuracy: 0.7540
# Epoch 56/100
# 63/63 [==============================] - 16s 253ms/step - loss: 0.5197 - accuracy: 0.7455 - val_loss: 0.4876 - val_accuracy: 0.7560
# Epoch 57/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.4970 - accuracy: 0.7625 - val_loss: 0.5035 - val_accuracy: 0.7520
# Epoch 58/100
# 63/63 [==============================] - 16s 258ms/step - loss: 0.5007 - accuracy: 0.7600 - val_loss: 0.4909 - val_accuracy: 0.7470
# Epoch 59/100
# 63/63 [==============================] - 17s 267ms/step - loss: 0.5064 - accuracy: 0.7520 - val_loss: 0.5252 - val_accuracy: 0.7300
# Epoch 60/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.5032 - accuracy: 0.7575 - val_loss: 0.5012 - val_accuracy: 0.7540
# Epoch 61/100
# 63/63 [==============================] - 16s 253ms/step - loss: 0.5017 - accuracy: 0.7490 - val_loss: 0.4655 - val_accuracy: 0.7670
# Epoch 62/100
# 63/63 [==============================] - 17s 268ms/step - loss: 0.5016 - accuracy: 0.7545 - val_loss: 0.4916 - val_accuracy: 0.7480
# Epoch 63/100
# 63/63 [==============================] - 17s 270ms/step - loss: 0.5013 - accuracy: 0.7480 - val_loss: 0.4902 - val_accuracy: 0.7560
# Epoch 64/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.5139 - accuracy: 0.7505 - val_loss: 0.5494 - val_accuracy: 0.7250
# Epoch 65/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.4961 - accuracy: 0.7580 - val_loss: 0.4638 - val_accuracy: 0.7680
# Epoch 66/100
# 63/63 [==============================] - 17s 270ms/step - loss: 0.4985 - accuracy: 0.7610 - val_loss: 0.4851 - val_accuracy: 0.7620
# Epoch 67/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4851 - accuracy: 0.7705 - val_loss: 0.4812 - val_accuracy: 0.7660
# Epoch 68/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4985 - accuracy: 0.7490 - val_loss: 0.4814 - val_accuracy: 0.7530
# Epoch 69/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.5042 - accuracy: 0.7565 - val_loss: 0.4632 - val_accuracy: 0.7680
# Epoch 70/100
# 63/63 [==============================] - 16s 256ms/step - loss: 0.5016 - accuracy: 0.7615 - val_loss: 0.4720 - val_accuracy: 0.7740
# Epoch 71/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.4923 - accuracy: 0.7580 - val_loss: 0.4725 - val_accuracy: 0.7590
# Epoch 72/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.5006 - accuracy: 0.7540 - val_loss: 0.4719 - val_accuracy: 0.7580
# Epoch 73/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.4898 - accuracy: 0.7670 - val_loss: 0.4583 - val_accuracy: 0.7780
# Epoch 74/100
# 63/63 [==============================] - 16s 249ms/step - loss: 0.4963 - accuracy: 0.7650 - val_loss: 0.4619 - val_accuracy: 0.7810
# Epoch 75/100
# 63/63 [==============================] - 17s 263ms/step - loss: 0.4831 - accuracy: 0.7730 - val_loss: 0.4801 - val_accuracy: 0.7650
# Epoch 76/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4878 - accuracy: 0.7645 - val_loss: 0.5147 - val_accuracy: 0.7500
# Epoch 77/100
# 63/63 [==============================] - 17s 275ms/step - loss: 0.4866 - accuracy: 0.7650 - val_loss: 0.4502 - val_accuracy: 0.7760
# Epoch 78/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4727 - accuracy: 0.7655 - val_loss: 0.4601 - val_accuracy: 0.7710
# Epoch 79/100
# 63/63 [==============================] - 16s 252ms/step - loss: 0.4838 - accuracy: 0.7630 - val_loss: 0.5698 - val_accuracy: 0.7160
# Epoch 80/100
# 63/63 [==============================] - 17s 272ms/step - loss: 0.4808 - accuracy: 0.7640 - val_loss: 0.4540 - val_accuracy: 0.7620
# Epoch 81/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.4874 - accuracy: 0.7690 - val_loss: 0.4663 - val_accuracy: 0.7820
# Epoch 82/100
# 63/63 [==============================] - 17s 264ms/step - loss: 0.4825 - accuracy: 0.7775 - val_loss: 0.4787 - val_accuracy: 0.7500
# Epoch 83/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.4789 - accuracy: 0.7690 - val_loss: 0.4797 - val_accuracy: 0.7710
# Epoch 84/100
# 63/63 [==============================] - 17s 274ms/step - loss: 0.4773 - accuracy: 0.7740 - val_loss: 0.4561 - val_accuracy: 0.7790
# Epoch 85/100
# 63/63 [==============================] - 16s 254ms/step - loss: 0.4701 - accuracy: 0.7730 - val_loss: 0.4821 - val_accuracy: 0.7690
# Epoch 86/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.4720 - accuracy: 0.7805 - val_loss: 0.4436 - val_accuracy: 0.7800
# Epoch 87/100
# 63/63 [==============================] - 16s 258ms/step - loss: 0.4741 - accuracy: 0.7785 - val_loss: 0.4590 - val_accuracy: 0.7850
# Epoch 88/100
# 63/63 [==============================] - 17s 269ms/step - loss: 0.4678 - accuracy: 0.7740 - val_loss: 0.4475 - val_accuracy: 0.7970
# Epoch 89/100
# 63/63 [==============================] - 17s 263ms/step - loss: 0.4636 - accuracy: 0.7815 - val_loss: 0.4601 - val_accuracy: 0.7800
# Epoch 90/100
# 63/63 [==============================] - 18s 278ms/step - loss: 0.4643 - accuracy: 0.7855 - val_loss: 0.5397 - val_accuracy: 0.7360
# Epoch 91/100
# 63/63 [==============================] - 16s 248ms/step - loss: 0.4495 - accuracy: 0.7870 - val_loss: 0.5289 - val_accuracy: 0.7510
# Epoch 92/100
# 63/63 [==============================] - 15s 242ms/step - loss: 0.4600 - accuracy: 0.7750 - val_loss: 0.4706 - val_accuracy: 0.7590
# Epoch 93/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.4603 - accuracy: 0.7790 - val_loss: 0.4453 - val_accuracy: 0.7830
# Epoch 94/100
# 63/63 [==============================] - 18s 279ms/step - loss: 0.4617 - accuracy: 0.7775 - val_loss: 0.4367 - val_accuracy: 0.7910
# Epoch 95/100
# 63/63 [==============================] - 16s 246ms/step - loss: 0.4535 - accuracy: 0.7880 - val_loss: 0.4459 - val_accuracy: 0.7880
# Epoch 96/100
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4523 - accuracy: 0.7935 - val_loss: 0.4522 - val_accuracy: 0.7860
# Epoch 97/100
# 63/63 [==============================] - 17s 265ms/step - loss: 0.4570 - accuracy: 0.7775 - val_loss: 0.5204 - val_accuracy: 0.7230
# Epoch 98/100
# 63/63 [==============================] - 17s 264ms/step - loss: 0.4587 - accuracy: 0.7965 - val_loss: 0.4332 - val_accuracy: 0.7970
# Epoch 99/100
# 63/63 [==============================] - 16s 250ms/step - loss: 0.4565 - accuracy: 0.7800 - val_loss: 0.4368 - val_accuracy: 0.7930
# Epoch 100/100
# 63/63 [==============================] - 15s 246ms/step - loss: 0.4572 - accuracy: 0.7855 - val_loss: 0.4849 - val_accuracy: 0.7720

# %% [markdown]
# 2.2. Muestra, de nuevo, la representación de los resultados del entrenamiento en dos gráficas, una para el accuracy y otra para el loss.

# %%
acc = history_with_dropout.history['accuracy']
val_acc = history_with_dropout.history['val_accuracy']
loss = history_with_dropout.history['loss']
val_loss = history_with_dropout.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'bo',label='Training accuracy')
plt.plot(epochs, val_acc, 'r',label='Validation accuracy')
plt.title('Training and validation accuracy - model')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo',label='Training loss')
plt.plot(epochs, val_loss, 'r',label='Validation loss')
plt.title('Training and validation loss - model')
plt.legend()

# %% [markdown]
# 2.3. ¿Qué conclusiones sacas viendo las gráficas?¿Ha mejorado el resultado del modelo?¿Hay overfitting? Comenta cualquier otra cosa que te haya llamado la atención.

# %% [markdown]
# - Parece que la grafica de training esta vez se adecua mucho mas a la de validation, evitando asi el overfitting al haber creado el generador de imagenes ademas de mejorando considerablemente el entrenamiento gracias al dropout.

# %% [markdown]
# ## 3. Modelo preentrenado VGG16 con "feature extraction" (BONUS)

# %% [markdown]
# Vamos a intentar mejorar el comportamiento de nuestro modelo recurriendo al modelo VGG16, entrenado con el famoso dataset de imágenes ImageNet. Para ello, debes importarlo de Keras, pasando los argumentos:
#
# - *weights ='imagenet'*, pues queremos usar los parámetros que resultan de haber entrenado esta arquitectura de capas con el dataset de ImageNet.
# - *include_top = False*, porque no queremos incluir la última capa de clasificación, que está configurada para distinguir entre 1000 clases de imágenes, y en nuestro caso tenemos solo dos.
# - *input_shape = (150,150,3)*

# %%
from keras.applications.vgg16 import VGG16

conv_base = VGG16(weights='imagenet',
include_top=False,
input_shape=(150, 150, 3))

conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Vamos a definir una función que extraiga las "features" principales de las imágenes que se le pasen a través del parametro directory.

# %%
batch_size = 20

def extract_features(directory, sample_count):
  features = np.zeros(shape=(sample_count, 4, 4, 512))
  labels = np.zeros(shape=(sample_count))
  generator = datagen.flow_from_directory(
      directory,
      target_size=(150, 150),
      batch_size=batch_size,
      class_mode='binary')
  i = 0
  for inputs_batch, labels_batch in generator:
    features_batch = conv_base.predict(inputs_batch)
    features[i * batch_size : (i + 1) * batch_size] = features_batch
    labels[i * batch_size : (i + 1) * batch_size] = labels_batch
    i += 1
    if i * batch_size >= sample_count:
      break
  return features, labels

# %% [markdown]
# 3.1. Crea un objeto generador datagen con ImageDataGenerator que solo normalice imágenes (dividiendo por 255). También, asigna a las variables train_features, train_labels lo que devuelve la función extract_features, con argumentos train_dir y 2000. Finalmente, asigna a las variables validation_features, validations_labels lo que devuelve la función extract_features al pasarle como argumentos validation_dir y 1000.

# %%
datagen = # escribe aquí la llamada a ImageDataGenerator

train_features, train_labels = # escribe aquí la llamada a la función con argumentos (train_dir, 2000)
validation_features, validation_labels = # escribe aquí la llamada a la función con argumentos (validation_dir, 1000)
# Out:
#   File "<ipython-input-29-931238767bf0>", line 1
#     datagen = # escribe aquí la llamada a ImageDataGenerator
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# Aplicamos reshape a las "features" extraidas para adaptarlas a las capas neuronales.

# %%
train_features = np.reshape(train_features, (2000, 4 * 4 * 512))
validation_features = np.reshape(validation_features, (1000, 4 * 4 * 512))

# %% [markdown]
# 3.2. Construye ahora un modelo con, al menos, dos capas de redes neuronales y, al menos, una capa dropout. En la primera capa, de tipo Dense, recuerda incluir el parámetro input_dim= 4*4*512

# %% [markdown]
# 3.3 Compila el modelo usando el optimizador RMSprop, loss 'binary_crossentropy' y metrics 'acc'. Entrena el modelo con train_features y train_labels como datos de entrada, y validation_features y validation_labels como datos de validación. Utiliza 20 epochs.

# %% [markdown]
# 3.4 Vuelve a representar las gráficas de entrenamiento

# %% [markdown]
# ¿Qué conclusiones puedes sacar? ¿Ha mejorado el desempeño del modelo?¿Hay overfitting?

# %% [markdown]
# ## 4. Fine-Tunning de modelo VGG16 (BONUS)

# %% [markdown]
# Finalmente, vamos a generar un nuevo modelo utilizando el modelo base de VGG16, pero, esta vez, reentrenarás el modelo, apartir de una serie de capas congeladas. Para facilitarte esta parte, te proporcionamos todas las celdas de código, pero debes ejecutarlas y añadir tus observaciones sobre la finalidad de las distintas partes de éste, además de indicar, en tu entrega final, las métricas que hayas conseguido alcanzar y tus propias conclusiones sobre qué modelo es mejor.

# %%
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_directory(train_dir)
valid_gen = ImageDataGenerator(preprocessing_function=preprocess_input).flow_from_directory(validation_dir)

# %%
vgg_model = VGG19(include_top=False, weights="imagenet", input_shape=(256, 256, 3))

for layer in vgg_model.layers[:12]:
  layer.trainable = False

# %%
model_ft = models.Sequential()

model_ft.add(vgg_model)

model_ft.add(layers.Flatten())
model_ft.add(layers.Dense(units=100, activation="relu"))
model_ft.add(layers.Dense(units=2,   activation="softmax"))

model_ft.summary()

# %%
model_ft.compile(optimizer=optimizers.Adam(learning_rate=1e-5),
              loss="categorical_crossentropy",
              metrics=["acc"])

history = model_ft.fit(train_gen, validation_data=valid_gen, epochs=20)

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy - Fine-Tunning')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss - Fine-Tunning')
plt.legend()

plt.show()
